# %%
#mandate lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#use case
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv("cancer.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-3dc3f04c9364> in <module>
# ----> 1 data = pd.read_csv("cancer.csv")
#       2 data.head()
#
# c:\program files\python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
sns.distplot(data['area_mean'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2db901e50f0b> in <module>
# ----> 1 sns.distplot(data['area_mean'])
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6208d269f320> in <module>
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.drop('Unnamed: 32', axis=1, inplace=True)
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.drop('id', axis=1, inplace=True)
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data['diagnosis']=data['diagnosis'].map({'M':1,'B':0})

# %%
data['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
corr=data.corr().round(2)
corr
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                     1.00         0.73          0.42            0.74
# radius_mean                   0.73         1.00          0.32            1.00
# texture_mean                  0.42         0.32          1.00            0.33
# perimeter_mean                0.74         1.00          0.33            1.00
# area_mean                     0.71         0.99          0.32            0.99
# smoothness_mean               0.36         0.17         -0.02            0.21
# compactness_mean              0.60         0.51          0.24            0.56
# concavity_mean                0.70         0.68          0.30            0.72
# concave points_mean           0.78         0.82          0.29            0.85
# symmetry_mean                 0.33         0.15          0.07            0.18
# fractal_dimension_mean       -0.01        -0.31         -0.08           -0.26
# ...

# %%
plt.figure(figsize=(18,15))
sns.heatmap(corr, cmap='coolwarm', annot=True, linewidth=0.5)

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
prediction_var = ['texture_mean', 'perimeter_mean','smoothness_mean', 'compactness_mean','symmetry_mean']

# %%
#shortcute for train, test
train, test = train_test_split(data, test_size=0.3, random_state=1)
print(train.shape, test.shape)
# Out:
# (398, 31) (171, 31)

# %%
train_x=train[prediction_var]
train_y=train.diagnosis
test_x=test[prediction_var]
test_y=test.diagnosis
print(train_x.shape, test_x.shape,train_y.shape, test_y.shape)
# Out:
# (398, 5) (171, 5) (398,) (171,)

# %%
lr = LogisticRegression()
lr.fit(train_x, train_y) # train
temp=lr.predict(test_x)
# Out:
# C:\Users\Harsharaj.raviraj\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
lr.score(test_x, test_y) # input test
# Out:
# 0.8830409356725146

# %%
metrics.accuracy_score(test_y,temp) # pred_y vs test_y
# Out:
# 0.8830409356725146

# %%
from sklearn.metrics import confusion_matrix
arr = confusion_matrix(test_y,temp) # array output
arr
df=pd.DataFrame(arr)
df
# Out:
#      0   1
# 0  104   4
# 1   16  47

# %%
print((104+47)/(104+4+16+47))
# Out:
# 0.8830409356725146

# %%
print("Test Accuracy - ",lr.score(test_x, test_y))
print("Train Accuracy - ",lr.score(train_x, train_y))
# Out:
# Test Accuracy -  0.8830409356725146
# Train Accuracy -  0.9045226130653267

# %% [markdown]
# train acc ~= test acc (margin 10-15%) - This safe model
# train acc >> test acc like train 95% and test gave 60%, model is overfitted i.e model is only predicting train data well
# train acc << test acc like test 85% and test train 60%, model is underfiited i.e model is only predicting train data well
#
# underfitting example
# train 60 - Apple was 90% but lemon gave me 35% overall 60%
# test 85% - Apple data and no lemon, this can e avoid using random_state or strafitication or random sampling.
